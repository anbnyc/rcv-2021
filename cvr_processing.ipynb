# %%
from openpyxl import load_workbook
import pandas as pd
import numpy as np
import json

# %% [markdown]
# #### Data prep
#
# Meant to be run from a directory with the following structure:
# ```
# current/
#   |- clean/
#   |- PE2021_CVR_Final/
#       |- (all the .xlsx files exactly as unzipped)
# ```
#
# Order of operations:
# * convert XLSX to CSV (`clean_and_save_files` which calls `xlsx_to_csv`)
# * load in Manhattan files from CSV (`make_county_file`)
# * get lookup table for candidate codes (`make_cand_lookup`)
# * create file for a specific race (`make_race_file`)

# %%
def xlsx_to_csv(key):
    wb = load_workbook('./PE2021_CVR_Final/'+ key +'.xlsx')
    ws = wb.active
    # df = pd.DataFrame(ws.values)
    
    data = ws.values
    cols = next(data)[1:]
    data = list(data)
    idx = [r[0] for r in data]
    data = (islice(r, 1, None) for r in data)
    df = pd.DataFrame(data, index=idx, columns=cols)
    
    # https://www.geeksforgeeks.org/python-pandas-split-strings-into-two-list-columns-using-str-split/
    # dropping null value columns to avoid errors
    df.dropna(inplace = True)

    # new data frame with split value columns
    new = df["Precinct"].str.split(" ", n = 4, expand = True)

    # # making separate first name column from new data frame
    df["AD"]= new[1]

    # # making separate last name column from new data frame
    df["ED"]= new[3]

    # # Dropping old Name columns
    df.drop(columns=["Precinct", "Ballot Style"], inplace = True)
    
    lead_cols = ['AD', 'ED']
    new_cols = lead_cols + [col for col in df.columns if col not in lead_cols]
    df = df = df[new_cols]
    
    df.to_csv('./clean/'+key+'.csv', index_label='id')

# %%
# TODO automate reading of directory
files = [
    "2021P1V1_ELE1",
    "2021P1V1_ELE2",
    "2021P1V1_ELE3",
    "2021P1V1_ABS",
    "2021P1V1_AFF",
    "2021P1V1_EMG",
]
def clean_and_save_files():
    for key in files:
        xlsx_to_csv(key)

# %%
# this only needs to be run once, and is time-consuming (~10 mins?)
# clean_and_save_files()

# %%
def make_county_file():
    # TODO make dynamic using file_names param
    ele1 = pd.read_csv('./clean/2021P1V1_ELE1.csv')
    ele2 = pd.read_csv('./clean/2021P1V1_ELE2.csv')
    ele3 = pd.read_csv('./clean/2021P1V1_ELE3.csv')
    _abs = pd.read_csv('./clean/2021P1V1_ABS.csv')
    _aff = pd.read_csv('./clean/2021P1V1_AFF.csv')
    _emg = pd.read_csv('./clean/2021P1V1_EMG.csv')
    
    # careful! for some reason this file has a different structure than the rest
    # only get the columns that are also in the other files
    _emg_match = _emg[ele1.columns]
    
    # sanity check: how many rows are in all of these files?
    print(ele1.shape[0] + ele2.shape[0] + ele3.shape[0] + _abs.shape[0] + _aff.shape[0] + _emg.shape[0])
    
    df = ele1.append(ele2).append(ele3).append(_abs).append(_aff).append(_emg_match)
    return df

# %%
df = make_county_file()
# Out:
# 274806

# %%
def make_cand_lookup():
    cands = pd.read_csv('./clean/2021P_CandidacyID_To_Name.csv')
    cand_ids = list(cands["CandidacyID"])
    cand_names = list(cands["DefaultBallotName"])
    cand_lookup = { str(id): cand_names[i] for i,id in enumerate(cand_ids) }
    
    # undervotes get skipped in the counting, but overvotes disqualify the vote in that race
    cand_lookup["undervote"] = "" 
#     cand_lookup["overvote"] = ""

    return cand_lookup

# %%
cand_lookup = make_cand_lookup()

# %%
# hard-coded values for Manhattan
# TODO make better data structure
col_lookup = {
    'bp': df.columns[3:8],
    'comp': df.columns[8:13],
    'cc2': df.columns[13:16],
    'cc10': df.columns[16:21],
    'cc1': df.columns[21:26],
    'cc3': df.columns[26:31],
    'cc5': df.columns[31:36],
    'cc6': df.columns[36:41],
    'cc7': df.columns[41:46],
    'cc8': df.columns[46:51],
    'cc9': df.columns[51:56],
    'mayor': df.columns[56:61],
    'pa': df.columns[61:65]
}
always_cols = ["id", "AD", "ED"]

def make_race_file(df, key):
    cols = list(col_lookup[key])

    # filter full table on votes where the first choice is not empty
    # this is a heuristic: at least one valid vote for a candidate in this race
    race_df = df[(df[cols[0]] != 'undervote')
                 | (df[cols[1]] != 'undervote')
                 | (df[cols[2]] != 'undervote')
                 | (df[cols[3]] != 'undervote')
                 | (df[cols[4]] != 'undervote')
                ][cols + always_cols]
    
    v_cols = always_cols
    for i,_v in enumerate(cols):
        v_col = "v"+str(i+1)
        race_df[v_col] = race_df[cols[i]].replace(cand_lookup)
        v_cols.append(v_col)
        
    return race_df[v_cols]

# %%
race_key = 'cc9'
race_df = make_race_file(df, race_key)
race_df

# %%
# race_df.to_csv('./clean/'+race_key+'.csv',index=False)

# %%
def keepdupe(row):
    new_row = []
    for r in row:
        if r != '':
            new_row.append(r)
    return ",".join(new_row)

def dedupe(row):
    new_row = []
    for r in row:
#         if r == 'overvote':
#             return ",".join(new_row)
        if r != '' and r not in new_row:
            new_row.append(r)
    return ",".join(new_row)

def make_agg_file(orig, should_dedupe=False):
    agg_df = orig.copy()
    
    if should_dedupe:
        agg_df["v"] = agg_df[["v1","v2","v3","v4","v5"]].apply(dedupe, axis=1)
    else:
        agg_df["v"] = agg_df[["v1","v2","v3","v4","v5"]].apply(keepdupe, axis=1)
    
    agg_grouped = agg_df.groupby("v")["v"].count().reset_index(name="count")

    vs = agg_grouped["v"].str.split(",", expand = True)

    agg_grouped["v1"] = vs[0]
    agg_grouped["v2"] = vs[1]
    agg_grouped["v3"] = vs[2]
    agg_grouped["v4"] = vs[3]
    agg_grouped["v5"] = vs[4]
    agg_grouped.fillna("", inplace=True)

    return agg_grouped

# %%
agg_grouped = make_agg_file(race_df, should_dedupe=True)
agg_grouped
# Out:
#                                                        v  count            v1  \
# 0                                           Athena Moore    426  Athena Moore
# 1                         Athena Moore,Bernadette McNear     10  Athena Moore
# 2            Athena Moore,Bernadette McNear,Bill Perkins      4  Athena Moore
# 3      Athena Moore,Bernadette McNear,Bill Perkins,Co...      1  Athena Moore
# 4      Athena Moore,Bernadette McNear,Bill Perkins,Ke...      1  Athena Moore
# ...                                                  ...    ...           ...
# 11669                          overvote,William A. Allen      3      overvote
# 11670  overvote,William A. Allen,Athena Moore,Sheba T...      1      overvote
# 11671             overvote,William A. Allen,Keith Taylor      1      overvote
# 11672  overvote,William A. Allen,Pierre A. Gooding,At...      1      overvote
# 11673  overvote,William A. Allen,Ruth L. McDaniels,Bi...      1      overvote
#
#                       v2                 v3                          v4  \
# 0
# 1      Bernadette McNear
# 2      Bernadette McNear       Bill Perkins
# 3      Bernadette McNear       Bill Perkins              Cordell Cleare
# 4      Bernadette McNear       Bill Perkins                Keith Taylor
# ...                  ...                ...                         ...
# 11669   William A. Allen
# 11670   William A. Allen       Athena Moore  Sheba T. Simpson-Amsterdam
# 11671   William A. Allen       Keith Taylor
# 11672   William A. Allen  Pierre A. Gooding                Athena Moore
# 11673   William A. Allen  Ruth L. McDaniels                Bill Perkins
#
#                           v5
# 0
# 1
# 2
# 3      Joshua Albert Clennon
# 4      Joshua Albert Clennon
# ...                      ...
# 11669
# 11670           Bill Perkins
# 11671
# 11672  Joshua Albert Clennon
# 11673           Athena Moore
#
# [11674 rows x 7 columns]

# %%
# agg_grouped.to_csv('./clean/'+race_key+'_grouped_dedupe.csv', index=False)

# %% [markdown]
# #### Analysis

# %%
# QA first-round votes
agg_grouped.groupby("v1").sum("count")
# Out:
#                             count
# v1
# Athena Moore                 2802
# Bernadette McNear             334
# Bill Perkins                 5409
# Billy Council                 736
# Cordell Cleare               2544
# Joshua Albert Clennon        1389
# Keith Taylor                 1432
# Kristin Richardson Jordan    4873
# Mario Rosser                 2176
# Pierre A. Gooding             732
# Ruth L. McDaniels             931
# Sheba T. Simpson-Amsterdam    583
# William A. Allen             1638
# Write-in                       47
# overvote                      147

# %%
# QA round 2 transfers from Write-in to candidates
# note: this does not account for multiple write-ins followed by a "real" candidate
agg_grouped[(agg_grouped["v1"] == "Write-in")].groupby("v2").sum("count")
# Out:
#                             count
# v2
#                                24
# Athena Moore                    4
# Bill Perkins                    6
# Cordell Cleare                  3
# Joshua Albert Clennon           1
# Keith Taylor                    1
# Kristin Richardson Jordan       2
# Mario Rosser                    2
# Pierre A. Gooding               2
# Ruth L. McDaniels               1
# Sheba T. Simpson-Amsterdam      1

# %%
ret = []
abbrevs = {
    'overvote': 'o',
    'Write-in': 'I',
    
    # bp
    'Ben Kallos': 'K',
    'Brad M. Hoylman': 'H',
    'Elizabeth R. Caputo': 'C',
    'Guillermo A. Perez': 'P',
    'Kimberly R. Watkins': 'W',
    'Lindsey C. Boylan': 'B',
    'Mark D. Levine': 'L',
    
    # cc7
    'Carmen R. Quinones': 'Q',
    'Corey Ortega': 'R',
    'Daniel M. Cohen': 'C',
    'Keith L. Harris': 'H',
    'Lena Melendez': 'D',
    'Luis Tejada': 'T',
    'Maria Ordonez': 'O',
    'Marti Gould  Allen-Cummings': 'M',
    'Miguel Estrella': 'E',
    'Raymond Sanchez Jr.': 'S',
    'Shaun Abreu': 'A',
    'Stacy R. Lynch': 'L',
    
    # cc6
    'David Gold': 'G',
    'Gale A. Brewer': 'B',
    'Jeffrey Omura': 'O',
    'Maria Danzilo': 'D',
    'Sara Lind': 'L',
    'Zachary Tov Weiner': 'W',
    
    # cc9
    'Bill Perkins': 'P',
    'Kristin Richardson Jordan': 'J',
    'Athena Moore': 'M',
    'Cordell Cleare': 'C',
    'Mario Rosser': 'R',
    'William A. Allen': 'A',
    'Keith Taylor': 'T',
    'Joshua Albert Clennon': 'L',
    'Ruth L. McDaniels': 'D',
    'Billy Council': 'O',
    'Pierre A. Gooding': 'G',
    'Sheba T. Simpson-Amsterdam': 'S',
    'Bernadette McNear': 'N'
}
for i,v in enumerate(agg_grouped["v"].str.split(",", expand=False)):
    ret.append({ "v": [abbrevs[e] for e in v], "votes": int(agg_grouped["count"][i]) })
ret
# Out:
# [{'v': ['M'], 'votes': 426},
#  {'v': ['M', 'N'], 'votes': 10},
#  {'v': ['M', 'N', 'P'], 'votes': 4},
#  {'v': ['M', 'N', 'P', 'C', 'L'], 'votes': 1},
#  {'v': ['M', 'N', 'P', 'T', 'L'], 'votes': 1},
#  {'v': ['M', 'N', 'P', 'D', 'J'], 'votes': 1},
#  {'v': ['M', 'N', 'P', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'N', 'P', 'S', 'D'], 'votes': 1},
#  {'v': ['M', 'N', 'P', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'N', 'O', 'G', 'D'], 'votes': 1},
#  {'v': ['M', 'N', 'O', 'S'], 'votes': 1},
#  {'v': ['M', 'N', 'C'], 'votes': 1},
#  {'v': ['M', 'N', 'C', 'P'], 'votes': 1},
#  {'v': ['M', 'N', 'C', 'P', 'D'], 'votes': 1},
#  {'v': ['M', 'N', 'C', 'G', 'J'], 'votes': 1},
#  {'v': ['M', 'N', 'C', 'G', 'S'], 'votes': 1},
#  {'v': ['M', 'N', 'C', 'D', 'P'], 'votes': 1},
#  {'v': ['M', 'N', 'C', 'S'], 'votes': 1},
#  {'v': ['M', 'N', 'C', 'S', 'P'], 'votes': 1},
#  {'v': ['M', 'N', 'L', 'A', 'O'], 'votes': 1},
#  {'v': ['M', 'N', 'T', 'P', 'G'], 'votes': 2},
#  {'v': ['M', 'N', 'T', 'P', 'D'], 'votes': 2},
#  {'v': ['M', 'N', 'T', 'O', 'D'], 'votes': 1},
#  {'v': ['M', 'N', 'T', 'O', 'A'], 'votes': 1},
#  {'v': ['M', 'N', 'T', 'L', 'S'], 'votes': 1},
#  {'v': ['M', 'N', 'T', 'J', 'L'], 'votes': 1},
#  {'v': ['M', 'N', 'T', 'D', 'P'], 'votes': 1},
#  {'v': ['M', 'N', 'T', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'N', 'J', 'C'], 'votes': 1},
#  {'v': ['M', 'N', 'J', 'C', 'R'], 'votes': 1},
#  {'v': ['M', 'N', 'J', 'L', 'R'], 'votes': 1},
#  {'v': ['M', 'N', 'J', 'R', 'S'], 'votes': 1},
#  {'v': ['M', 'N', 'J', 'G', 'A'], 'votes': 1},
#  {'v': ['M', 'N', 'J', 'D', 'R'], 'votes': 1},
#  {'v': ['M', 'N', 'J', 'D', 'S'], 'votes': 3},
#  {'v': ['M', 'N', 'J', 'S', 'P'], 'votes': 1},
#  {'v': ['M', 'N', 'J', 'S', 'C'], 'votes': 1},
#  {'v': ['M', 'N', 'J', 'S', 'R'], 'votes': 1},
#  {'v': ['M', 'N', 'J', 'A', 'G'], 'votes': 1},
#  {'v': ['M', 'N', 'R'], 'votes': 2},
#  {'v': ['M', 'N', 'R', 'P'], 'votes': 1},
#  {'v': ['M', 'N', 'R', 'C', 'P'], 'votes': 1},
#  {'v': ['M', 'N', 'R', 'C', 'O'], 'votes': 2},
#  {'v': ['M', 'N', 'R', 'T', 'O'], 'votes': 1},
#  {'v': ['M', 'N', 'R', 'J', 'C'], 'votes': 1},
#  {'v': ['M', 'N', 'R', 'S', 'A'], 'votes': 1},
#  {'v': ['M', 'N', 'R', 'A', 'C'], 'votes': 1},
#  {'v': ['M', 'N', 'G', 'C', 'L'], 'votes': 1},
#  {'v': ['M', 'N', 'G', 'J', 'D'], 'votes': 1},
#  {'v': ['M', 'N', 'G', 'D', 'R'], 'votes': 1},
#  {'v': ['M', 'N', 'D'], 'votes': 5},
#  {'v': ['M', 'N', 'D', 'P', 'T'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'P', 'S'], 'votes': 3},
#  {'v': ['M', 'N', 'D', 'P', 'A'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'O', 'S'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'C', 'L'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'C', 'T'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'C', 'J'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'C', 'S'], 'votes': 3},
#  {'v': ['M', 'N', 'D', 'L', 'T'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'T'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'T', 'P'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'T', 'C'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'T', 'L'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'T', 'J'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'T', 'S'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'J'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'J', 'S'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'R'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'R', 'P'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'R', 'L'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'R', 'A'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'G', 'P'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'G', 'S'], 'votes': 2},
#  {'v': ['M', 'N', 'D', 'S'], 'votes': 5},
#  {'v': ['M', 'N', 'D', 'S', 'P'], 'votes': 2},
#  {'v': ['M', 'N', 'D', 'S', 'O'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'S', 'T'], 'votes': 1},
#  {'v': ['M', 'N', 'D', 'S', 'J'], 'votes': 4},
#  {'v': ['M', 'N', 'D', 'S', 'G'], 'votes': 2},
#  {'v': ['M', 'N', 'D', 'S', 'I'], 'votes': 1},
#  {'v': ['M', 'N', 'S'], 'votes': 6},
#  {'v': ['M', 'N', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'N', 'S', 'L', 'R'], 'votes': 1},
#  {'v': ['M', 'N', 'S', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'N', 'S', 'J', 'D'], 'votes': 2},
#  {'v': ['M', 'N', 'S', 'J', 'I'], 'votes': 1},
#  {'v': ['M', 'N', 'S', 'R', 'J'], 'votes': 1},
#  {'v': ['M', 'N', 'S', 'G'], 'votes': 1},
#  {'v': ['M', 'N', 'S', 'D', 'P'], 'votes': 1},
#  {'v': ['M', 'N', 'S', 'D', 'C'], 'votes': 1},
#  {'v': ['M', 'N', 'S', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'N', 'A'], 'votes': 1},
#  {'v': ['M', 'N', 'A', 'J', 'R'], 'votes': 1},
#  {'v': ['M', 'N', 'I', 'S', 'O'], 'votes': 1},
#  {'v': ['M', 'P'], 'votes': 88},
#  {'v': ['M', 'P', 'N'], 'votes': 3},
#  {'v': ['M', 'P', 'N', 'L', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'N', 'T', 'L'], 'votes': 1},
#  {'v': ['M', 'P', 'N', 'J'], 'votes': 1},
#  {'v': ['M', 'P', 'N', 'J', 'R'], 'votes': 1},
#  {'v': ['M', 'P', 'N', 'J', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'N', 'R', 'L'], 'votes': 1},
#  {'v': ['M', 'P', 'N', 'S'], 'votes': 1},
#  {'v': ['M', 'P', 'N', 'S', 'R'], 'votes': 1},
#  {'v': ['M', 'P', 'O'], 'votes': 1},
#  {'v': ['M', 'P', 'O', 'C', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'O', 'C', 'J'], 'votes': 1},
#  {'v': ['M', 'P', 'O', 'L'], 'votes': 1},
#  {'v': ['M', 'P', 'O', 'G', 'S'], 'votes': 1},
#  {'v': ['M', 'P', 'O', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'P', 'O', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'O', 'A', 'S'], 'votes': 1},
#  {'v': ['M', 'P', 'C'], 'votes': 7},
#  {'v': ['M', 'P', 'C', 'N'], 'votes': 1},
#  {'v': ['M', 'P', 'C', 'O', 'L'], 'votes': 1},
#  {'v': ['M', 'P', 'C', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'C', 'J'], 'votes': 1},
#  {'v': ['M', 'P', 'C', 'J', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'C', 'J', 'G'], 'votes': 1},
#  {'v': ['M', 'P', 'C', 'G', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'C', 'G', 'A'], 'votes': 1},
#  {'v': ['M', 'P', 'C', 'D', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'C', 'S', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'C', 'A'], 'votes': 1},
#  {'v': ['M', 'P', 'C', 'A', 'N'], 'votes': 1},
#  {'v': ['M', 'P', 'C', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'L'], 'votes': 4},
#  {'v': ['M', 'P', 'L', 'O', 'R'], 'votes': 1},
#  {'v': ['M', 'P', 'L', 'J', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'L', 'G', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'L', 'S', 'J'], 'votes': 1},
#  {'v': ['M', 'P', 'T'], 'votes': 11},
#  {'v': ['M', 'P', 'T', 'N', 'G'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'N', 'D'], 'votes': 2},
#  {'v': ['M', 'P', 'T', 'N', 'A'], 'votes': 2},
#  {'v': ['M', 'P', 'T', 'O'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'O', 'C'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'O', 'L'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'O', 'S'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'L', 'R'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'L', 'G'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'J', 'N'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'J', 'D'], 'votes': 2},
#  {'v': ['M', 'P', 'T', 'J', 'A'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'R'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'R', 'J'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'D'], 'votes': 2},
#  {'v': ['M', 'P', 'T', 'D', 'J'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'D', 'G'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'D', 'A'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'S', 'N'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'S', 'A'], 'votes': 1},
#  {'v': ['M', 'P', 'T', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'J'], 'votes': 4},
#  {'v': ['M', 'P', 'J', 'N', 'D'], 'votes': 2},
#  {'v': ['M', 'P', 'J', 'C', 'S'], 'votes': 1},
#  {'v': ['M', 'P', 'J', 'C', 'A'], 'votes': 1},
#  {'v': ['M', 'P', 'J', 'L'], 'votes': 1},
#  {'v': ['M', 'P', 'J', 'L', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'J', 'L', 'A'], 'votes': 1},
#  {'v': ['M', 'P', 'J', 'T', 'O'], 'votes': 1},
#  {'v': ['M', 'P', 'J', 'T', 'L'], 'votes': 1},
#  {'v': ['M', 'P', 'J', 'R', 'O'], 'votes': 1},
#  {'v': ['M', 'P', 'J', 'D', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'J', 'D', 'G'], 'votes': 1},
#  {'v': ['M', 'P', 'J', 'A'], 'votes': 1},
#  {'v': ['M', 'P', 'J', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'R'], 'votes': 1},
#  {'v': ['M', 'P', 'R', 'T', 'A'], 'votes': 1},
#  {'v': ['M', 'P', 'R', 'J', 'L'], 'votes': 1},
#  {'v': ['M', 'P', 'R', 'G', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'R', 'S', 'N'], 'votes': 1},
#  {'v': ['M', 'P', 'R', 'A', 'O'], 'votes': 1},
#  {'v': ['M', 'P', 'R', 'A', 'C'], 'votes': 1},
#  {'v': ['M', 'P', 'G'], 'votes': 1},
#  {'v': ['M', 'P', 'G', 'N', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'G', 'N', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'G', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'G', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'G', 'J', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'G', 'J', 'S'], 'votes': 1},
#  {'v': ['M', 'P', 'G', 'R', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'G', 'D', 'L'], 'votes': 1},
#  {'v': ['M', 'P', 'G', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'N', 'L'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'N', 'J'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'N', 'G'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'N', 'S'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'O', 'L'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'T', 'G'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'T', 'S'], 'votes': 2},
#  {'v': ['M', 'P', 'D', 'J'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'J', 'C'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'J', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'J', 'G'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'J', 'S'], 'votes': 2},
#  {'v': ['M', 'P', 'D', 'S'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'S', 'J'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'D', 'A', 'S'], 'votes': 1},
#  {'v': ['M', 'P', 'S'], 'votes': 5},
#  {'v': ['M', 'P', 'S', 'N', 'D'], 'votes': 2},
#  {'v': ['M', 'P', 'S', 'C', 'G'], 'votes': 1},
#  {'v': ['M', 'P', 'S', 'L', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'S', 'T', 'R'], 'votes': 1},
#  {'v': ['M', 'P', 'S', 'J', 'N'], 'votes': 1},
#  {'v': ['M', 'P', 'S', 'J', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'S', 'R'], 'votes': 1},
#  {'v': ['M', 'P', 'S', 'G', 'J'], 'votes': 1},
#  {'v': ['M', 'P', 'S', 'D', 'N'], 'votes': 1},
#  {'v': ['M', 'P', 'S', 'D', 'C'], 'votes': 1},
#  {'v': ['M', 'P', 'S', 'D', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'S', 'A', 'J'], 'votes': 1},
#  {'v': ['M', 'P', 'A'], 'votes': 2},
#  {'v': ['M', 'P', 'A', 'C'], 'votes': 3},
#  {'v': ['M', 'P', 'A', 'C', 'N'], 'votes': 1},
#  {'v': ['M', 'P', 'A', 'C', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'A', 'T', 'J'], 'votes': 1},
#  {'v': ['M', 'P', 'A', 'T', 'G'], 'votes': 3},
#  {'v': ['M', 'P', 'A', 'J', 'D'], 'votes': 1},
#  {'v': ['M', 'P', 'A', 'G', 'T'], 'votes': 1},
#  {'v': ['M', 'P', 'A', 'D', 'T'], 'votes': 2},
#  {'v': ['M', 'P', 'A', 'D', 'G'], 'votes': 1},
#  {'v': ['M', 'O'], 'votes': 12},
#  {'v': ['M', 'O', 'P'], 'votes': 3},
#  {'v': ['M', 'O', 'P', 'T', 'J'], 'votes': 1},
#  {'v': ['M', 'O', 'C'], 'votes': 1},
#  {'v': ['M', 'O', 'C', 'P', 'N'], 'votes': 1},
#  {'v': ['M', 'O', 'C', 'P', 'T'], 'votes': 1},
#  {'v': ['M', 'O', 'C', 'T', 'R'], 'votes': 1},
#  {'v': ['M', 'O', 'C', 'T', 'A'], 'votes': 1},
#  {'v': ['M', 'O', 'C', 'D', 'N'], 'votes': 1},
#  {'v': ['M', 'O', 'L', 'T'], 'votes': 1},
#  {'v': ['M', 'O', 'L', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'O', 'L', 'R', 'N'], 'votes': 1},
#  {'v': ['M', 'O', 'T'], 'votes': 1},
#  {'v': ['M', 'O', 'T', 'C', 'P'], 'votes': 1},
#  {'v': ['M', 'O', 'T', 'R', 'J'], 'votes': 1},
#  {'v': ['M', 'O', 'T', 'S', 'G'], 'votes': 1},
#  {'v': ['M', 'O', 'T', 'A', 'G'], 'votes': 1},
#  {'v': ['M', 'O', 'J'], 'votes': 1},
#  {'v': ['M', 'O', 'J', 'P', 'C'], 'votes': 1},
#  {'v': ['M', 'O', 'J', 'R', 'T'], 'votes': 1},
#  {'v': ['M', 'O', 'R'], 'votes': 1},
#  {'v': ['M', 'O', 'R', 'T', 'P'], 'votes': 1},
#  {'v': ['M', 'O', 'R', 'T', 'G'], 'votes': 1},
#  {'v': ['M', 'O', 'R', 'G', 'T'], 'votes': 1},
#  {'v': ['M', 'O', 'R', 'D', 'T'], 'votes': 1},
#  {'v': ['M', 'O', 'R', 'S', 'J'], 'votes': 1},
#  {'v': ['M', 'O', 'R', 'A', 'P'], 'votes': 1},
#  {'v': ['M', 'O', 'G', 'T'], 'votes': 1},
#  {'v': ['M', 'O', 'D', 'N', 'A'], 'votes': 1},
#  {'v': ['M', 'O', 'D', 'J', 'S'], 'votes': 1},
#  {'v': ['M', 'O', 'S'], 'votes': 1},
#  {'v': ['M', 'O', 'S', 'C', 'D'], 'votes': 1},
#  {'v': ['M', 'O', 'S', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'O', 'S', 'G', 'T'], 'votes': 1},
#  {'v': ['M', 'O', 'A', 'C', 'D'], 'votes': 1},
#  {'v': ['M', 'O', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'C'], 'votes': 53},
#  {'v': ['M', 'C', 'N'], 'votes': 1},
#  {'v': ['M', 'C', 'N', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'N', 'J', 'S'], 'votes': 1},
#  {'v': ['M', 'C', 'N', 'S', 'G'], 'votes': 1},
#  {'v': ['M', 'C', 'P'], 'votes': 12},
#  {'v': ['M', 'C', 'P', 'N', 'O'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'O'], 'votes': 2},
#  {'v': ['M', 'C', 'P', 'L'], 'votes': 3},
#  {'v': ['M', 'C', 'P', 'L', 'N'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'T', 'O'], 'votes': 2},
#  {'v': ['M', 'C', 'P', 'T', 'R'], 'votes': 2},
#  {'v': ['M', 'C', 'P', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'T', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'J', 'G'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'J', 'S'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'J', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'R', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'R', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'G', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'D', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'D', 'I'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'A'], 'votes': 2},
#  {'v': ['M', 'C', 'P', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'A', 'G'], 'votes': 1},
#  {'v': ['M', 'C', 'P', 'A', 'S'], 'votes': 1},
#  {'v': ['M', 'C', 'O'], 'votes': 5},
#  {'v': ['M', 'C', 'O', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'O', 'L', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'O', 'T', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'O', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'O', 'J', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'O', 'J', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'O', 'D', 'G'], 'votes': 1},
#  {'v': ['M', 'C', 'O', 'S', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'O', 'S', 'G'], 'votes': 1},
#  {'v': ['M', 'C', 'O', 'A', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'O', 'A', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'L'], 'votes': 12},
#  {'v': ['M', 'C', 'L', 'N', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'O', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'T'], 'votes': 2},
#  {'v': ['M', 'C', 'L', 'T', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'J'], 'votes': 3},
#  {'v': ['M', 'C', 'L', 'J', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'R', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'R', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'R', 'J'], 'votes': 3},
#  {'v': ['M', 'C', 'L', 'R', 'G'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'R', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'G', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'G', 'J'], 'votes': 2},
#  {'v': ['M', 'C', 'L', 'G', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'G', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'D', 'N'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'D', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'A', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'L', 'A', 'S'], 'votes': 1},
#  {'v': ['M', 'C', 'T'], 'votes': 9},
#  {'v': ['M', 'C', 'T', 'N'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'N', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'P'], 'votes': 2},
#  {'v': ['M', 'C', 'T', 'P', 'N'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'P', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'P', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'P', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'O'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'L', 'O'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'L', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'L', 'A'], 'votes': 2},
#  {'v': ['M', 'C', 'T', 'J', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'R', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'R', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'R', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'R', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'D', 'O'], 'votes': 2},
#  {'v': ['M', 'C', 'T', 'D', 'S'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'D', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'S'], 'votes': 2},
#  {'v': ['M', 'C', 'T', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'S', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'T', 'A', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'J'], 'votes': 18},
#  {'v': ['M', 'C', 'J', 'N', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'N', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'N', 'S'], 'votes': 2},
#  {'v': ['M', 'C', 'J', 'P', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'P', 'S'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'L', 'T'], 'votes': 2},
#  {'v': ['M', 'C', 'J', 'L', 'R'], 'votes': 2},
#  {'v': ['M', 'C', 'J', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'T', 'O'], 'votes': 2},
#  {'v': ['M', 'C', 'J', 'T', 'L'], 'votes': 3},
#  {'v': ['M', 'C', 'J', 'T', 'G'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'R'], 'votes': 5},
#  {'v': ['M', 'C', 'J', 'R', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'R', 'O'], 'votes': 2},
#  {'v': ['M', 'C', 'J', 'R', 'L'], 'votes': 2},
#  {'v': ['M', 'C', 'J', 'R', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'G'], 'votes': 2},
#  {'v': ['M', 'C', 'J', 'G', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'D', 'N'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'D', 'L'], 'votes': 2},
#  {'v': ['M', 'C', 'J', 'D', 'R'], 'votes': 2},
#  {'v': ['M', 'C', 'J', 'D', 'S'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'S'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'A', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'J', 'A', 'D'], 'votes': 2},
#  {'v': ['M', 'C', 'R'], 'votes': 9},
#  {'v': ['M', 'C', 'R', 'N', 'D'], 'votes': 2},
#  {'v': ['M', 'C', 'R', 'P'], 'votes': 2},
#  {'v': ['M', 'C', 'R', 'P', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'P', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'P', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'P', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'O', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'O', 'G'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'L'], 'votes': 3},
#  {'v': ['M', 'C', 'R', 'L', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'L', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'T', 'O'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'T', 'L'], 'votes': 2},
#  {'v': ['M', 'C', 'R', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'J', 'O'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'J', 'G'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'J', 'S'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'G', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'G', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'G', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'D'], 'votes': 2},
#  {'v': ['M', 'C', 'R', 'S', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'A', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'R', 'A', 'G'], 'votes': 1},
#  {'v': ['M', 'C', 'G'], 'votes': 3},
#  {'v': ['M', 'C', 'G', 'P', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'G', 'L', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'G', 'L', 'S'], 'votes': 1},
#  {'v': ['M', 'C', 'G', 'L', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'G', 'T', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'G', 'J', 'N'], 'votes': 2},
#  {'v': ['M', 'C', 'G', 'J', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'G', 'D', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'G', 'S', 'N'], 'votes': 1},
#  {'v': ['M', 'C', 'G', 'A', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'G', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'G', 'A', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'G', 'A', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'G', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'D'], 'votes': 6},
#  {'v': ['M', 'C', 'D', 'N', 'S'], 'votes': 4},
#  {'v': ['M', 'C', 'D', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'D', 'P', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'D', 'O', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'D', 'O', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'D', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'D', 'J', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'D', 'J', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'D', 'J', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'D', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'D', 'S', 'G'], 'votes': 1},
#  {'v': ['M', 'C', 'S'], 'votes': 2},
#  {'v': ['M', 'C', 'S', 'N', 'D'], 'votes': 2},
#  {'v': ['M', 'C', 'S', 'P', 'A'], 'votes': 1},
#  {'v': ['M', 'C', 'S', 'T', 'O'], 'votes': 1},
#  {'v': ['M', 'C', 'S', 'T', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'S', 'J'], 'votes': 2},
#  {'v': ['M', 'C', 'S', 'J', 'N'], 'votes': 1},
#  {'v': ['M', 'C', 'S', 'J', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'S', 'D', 'N'], 'votes': 2},
#  {'v': ['M', 'C', 'A'], 'votes': 8},
#  {'v': ['M', 'C', 'A', 'N', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'P', 'N'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'P', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'P', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'O', 'R'], 'votes': 2},
#  {'v': ['M', 'C', 'A', 'L'], 'votes': 2},
#  {'v': ['M', 'C', 'A', 'L', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'L', 'O'], 'votes': 3},
#  {'v': ['M', 'C', 'A', 'L', 'R'], 'votes': 2},
#  {'v': ['M', 'C', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'T', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'J', 'P'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'J', 'L'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'J', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'R'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'R', 'T'], 'votes': 3},
#  {'v': ['M', 'C', 'A', 'R', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'G', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'D', 'J'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'D', 'G'], 'votes': 1},
#  {'v': ['M', 'C', 'A', 'D', 'S'], 'votes': 1},
#  {'v': ['M', 'L'], 'votes': 14},
#  {'v': ['M', 'L', 'P'], 'votes': 2},
#  {'v': ['M', 'L', 'P', 'N', 'A'], 'votes': 1},
#  {'v': ['M', 'L', 'P', 'T', 'C'], 'votes': 1},
#  {'v': ['M', 'L', 'P', 'T', 'J'], 'votes': 1},
#  {'v': ['M', 'L', 'P', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'L', 'O'], 'votes': 1},
#  {'v': ['M', 'L', 'O', 'C', 'R'], 'votes': 1},
#  {'v': ['M', 'L', 'O', 'J', 'C'], 'votes': 1},
#  {'v': ['M', 'L', 'O', 'J', 'R'], 'votes': 1},
#  {'v': ['M', 'L', 'O', 'D', 'S'], 'votes': 1},
#  {'v': ['M', 'L', 'C'], 'votes': 2},
#  {'v': ['M', 'L', 'C', 'P'], 'votes': 2},
#  {'v': ['M', 'L', 'C', 'O'], 'votes': 1},
#  {'v': ['M', 'L', 'C', 'T', 'N'], 'votes': 1},
#  {'v': ['M', 'L', 'C', 'T', 'R'], 'votes': 2},
#  {'v': ['M', 'L', 'C', 'J'], 'votes': 1},
#  {'v': ['M', 'L', 'C', 'J', 'R'], 'votes': 9},
#  {'v': ['M', 'L', 'C', 'J', 'D'], 'votes': 1},
#  {'v': ['M', 'L', 'C', 'R'], 'votes': 1},
#  {'v': ['M', 'L', 'C', 'R', 'J'], 'votes': 2},
#  {'v': ['M', 'L', 'C', 'R', 'G'], 'votes': 1},
#  {'v': ['M', 'L', 'T', 'C', 'D'], 'votes': 1},
#  {'v': ['M', 'L', 'T', 'J', 'D'], 'votes': 1},
#  {'v': ['M', 'L', 'T', 'G', 'S'], 'votes': 1},
#  {'v': ['M', 'L', 'J'], 'votes': 5},
#  {'v': ['M', 'L', 'J', 'N', 'C'], 'votes': 1},
#  {'v': ['M', 'L', 'J', 'N', 'D'], 'votes': 1},
#  {'v': ['M', 'L', 'J', 'C', 'R'], 'votes': 1},
#  {'v': ['M', 'L', 'J', 'C', 'D'], 'votes': 1},
#  {'v': ['M', 'L', 'J', 'C', 'A'], 'votes': 1},
#  {'v': ['M', 'L', 'J', 'T', 'C'], 'votes': 1},
#  {'v': ['M', 'L', 'J', 'T', 'A'], 'votes': 1},
#  {'v': ['M', 'L', 'J', 'R', 'N'], 'votes': 1},
#  {'v': ['M', 'L', 'J', 'R', 'T'], 'votes': 1},
#  {'v': ['M', 'L', 'J', 'D', 'N'], 'votes': 1},
#  {'v': ['M', 'L', 'J', 'A', 'P'], 'votes': 1},
#  {'v': ['M', 'L', 'J', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'L', 'R'], 'votes': 2},
#  {'v': ['M', 'L', 'R', 'O', 'S'], 'votes': 1},
#  {'v': ['M', 'L', 'R', 'C', 'T'], 'votes': 3},
#  {'v': ['M', 'L', 'R', 'C', 'J'], 'votes': 1},
#  {'v': ['M', 'L', 'R', 'T', 'C'], 'votes': 1},
#  {'v': ['M', 'L', 'R', 'T', 'J'], 'votes': 1},
#  {'v': ['M', 'L', 'R', 'J'], 'votes': 2},
#  {'v': ['M', 'L', 'R', 'J', 'C'], 'votes': 1},
#  {'v': ['M', 'L', 'R', 'G', 'S'], 'votes': 1},
#  {'v': ['M', 'L', 'R', 'A'], 'votes': 2},
#  {'v': ['M', 'L', 'R', 'A', 'O'], 'votes': 1},
#  {'v': ['M', 'L', 'G'], 'votes': 1},
#  {'v': ['M', 'L', 'G', 'C'], 'votes': 1},
#  {'v': ['M', 'L', 'G', 'C', 'N'], 'votes': 1},
#  {'v': ['M', 'L', 'D'], 'votes': 3},
#  {'v': ['M', 'L', 'D', 'N', 'O'], 'votes': 1},
#  {'v': ['M', 'L', 'D', 'C', 'G'], 'votes': 1},
#  {'v': ['M', 'L', 'D', 'J'], 'votes': 1},
#  {'v': ['M', 'L', 'D', 'R', 'S'], 'votes': 1},
#  {'v': ['M', 'L', 'S'], 'votes': 1},
#  {'v': ['M', 'L', 'S', 'C', 'G'], 'votes': 1},
#  {'v': ['M', 'L', 'S', 'T', 'R'], 'votes': 1},
#  {'v': ['M', 'L', 'S', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'L', 'S', 'J'], 'votes': 2},
#  {'v': ['M', 'L', 'S', 'G', 'P'], 'votes': 1},
#  {'v': ['M', 'L', 'A', 'G', 'T'], 'votes': 1},
#  {'v': ['M', 'T'], 'votes': 30},
#  {'v': ['M', 'T', 'N', 'P', 'J'], 'votes': 1},
#  {'v': ['M', 'T', 'N', 'O', 'I'], 'votes': 1},
#  {'v': ['M', 'T', 'N', 'C', 'P'], 'votes': 1},
#  {'v': ['M', 'T', 'N', 'J', 'P'], 'votes': 1},
#  {'v': ['M', 'T', 'N', 'J', 'S'], 'votes': 1},
#  {'v': ['M', 'T', 'N', 'D'], 'votes': 2},
#  {'v': ['M', 'T', 'N', 'D', 'P'], 'votes': 1},
#  {'v': ['M', 'T', 'N', 'D', 'O'], 'votes': 1},
#  {'v': ['M', 'T', 'N', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'T', 'P'], 'votes': 11},
#  {'v': ['M', 'T', 'P', 'O'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'O', 'N'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'O', 'R'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'O', 'S'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'L'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'L', 'J'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'L', 'A'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'J', 'D'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'J', 'A'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'R', 'L'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'R', 'G'], 'votes': 2},
#  {'v': ['M', 'T', 'P', 'G', 'A'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'S', 'J'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'S', 'G'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'A', 'N'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'A', 'J'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'T', 'P', 'I'], 'votes': 1},
#  {'v': ['M', 'T', 'O'], 'votes': 3},
#  {'v': ['M', 'T', 'O', 'C', 'J'], 'votes': 1},
#  {'v': ['M', 'T', 'O', 'L', 'C'], 'votes': 1},
#  {'v': ['M', 'T', 'O', 'L', 'A'], 'votes': 1},
#  {'v': ['M', 'T', 'C'], 'votes': 3},
#  {'v': ['M', 'T', 'C', 'P'], 'votes': 3},
#  {'v': ['M', 'T', 'C', 'P', 'G'], 'votes': 1},
#  {'v': ['M', 'T', 'C', 'L', 'P'], 'votes': 1},
#  {'v': ['M', 'T', 'C', 'L', 'J'], 'votes': 1},
#  {'v': ['M', 'T', 'C', 'J', 'R'], 'votes': 1},
#  {'v': ['M', 'T', 'C', 'J', 'A'], 'votes': 1},
#  {'v': ['M', 'T', 'C', 'R'], 'votes': 1},
#  {'v': ['M', 'T', 'C', 'R', 'A'], 'votes': 2},
#  {'v': ['M', 'T', 'C', 'G', 'N'], 'votes': 1},
#  {'v': ['M', 'T', 'C', 'G', 'L'], 'votes': 1},
#  {'v': ['M', 'T', 'C', 'D', 'P'], 'votes': 1},
#  {'v': ['M', 'T', 'C', 'S', 'N'], 'votes': 1},
#  {'v': ['M', 'T', 'C', 'A', 'P'], 'votes': 1},
#  {'v': ['M', 'T', 'L'], 'votes': 3},
#  {'v': ['M', 'T', 'L', 'C', 'P'], 'votes': 2},
#  {'v': ['M', 'T', 'L', 'C', 'O'], 'votes': 1},
#  {'v': ['M', 'T', 'L', 'J'], 'votes': 1},
#  {'v': ['M', 'T', 'L', 'J', 'R'], 'votes': 1},
#  {'v': ['M', 'T', 'L', 'R', 'C'], 'votes': 1},
#  {'v': ['M', 'T', 'L', 'D'], 'votes': 1},
#  {'v': ['M', 'T', 'L', 'D', 'C'], 'votes': 1},
#  {'v': ['M', 'T', 'L', 'S'], 'votes': 1},
#  {'v': ['M', 'T', 'J'], 'votes': 3},
#  {'v': ['M', 'T', 'J', 'P', 'S'], 'votes': 1},
#  {'v': ['M', 'T', 'J', 'C'], 'votes': 1},
#  {'v': ['M', 'T', 'J', 'C', 'P'], 'votes': 1},
#  {'v': ['M', 'T', 'J', 'R', 'G'], 'votes': 1},
#  {'v': ['M', 'T', 'J', 'D', 'S'], 'votes': 1},
#  {'v': ['M', 'T', 'J', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'N', 'C'], 'votes': 2},
#  {'v': ['M', 'T', 'R', 'P'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'P', 'G'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'P', 'D'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'O'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'O', 'J'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'O', 'S'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'C'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'C', 'A'], 'votes': 2},
#  {'v': ['M', 'T', 'R', 'L', 'J'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'J', 'P'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'J', 'G'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'G', 'L'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'G', 'S'], 'votes': 2},
#  {'v': ['M', 'T', 'R', 'S'], 'votes': 1},
#  {'v': ['M', 'T', 'R', 'A', 'G'], 'votes': 1},
#  {'v': ['M', 'T', 'G'], 'votes': 2},
#  {'v': ['M', 'T', 'G', 'J', 'C'], 'votes': 1},
#  {'v': ['M', 'T', 'G', 'R', 'C'], 'votes': 1},
#  {'v': ['M', 'T', 'D', 'P', 'O'], 'votes': 1},
#  {'v': ['M', 'T', 'D', 'J', 'P'], 'votes': 1},
#  {'v': ['M', 'T', 'D', 'J', 'G'], 'votes': 2},
#  {'v': ['M', 'T', 'D', 'R'], 'votes': 2},
#  {'v': ['M', 'T', 'D', 'G', 'R'], 'votes': 1},
#  {'v': ['M', 'T', 'D', 'S', 'P'], 'votes': 1},
#  {'v': ['M', 'T', 'D', 'A', 'P'], 'votes': 1},
#  {'v': ['M', 'T', 'D', 'A', 'G'], 'votes': 1},
#  {'v': ['M', 'T', 'D', 'I', 'J'], 'votes': 1},
#  {'v': ['M', 'T', 'S'], 'votes': 4},
#  {'v': ['M', 'T', 'S', 'O', 'J'], 'votes': 1},
#  {'v': ['M', 'T', 'S', 'J', 'L'], 'votes': 1},
#  {'v': ['M', 'T', 'S', 'R'], 'votes': 1},
#  {'v': ['M', 'T', 'S', 'I'], 'votes': 1},
#  {'v': ['M', 'T', 'A'], 'votes': 6},
#  {'v': ['M', 'T', 'A', 'N', 'D'], 'votes': 1},
#  {'v': ['M', 'T', 'A', 'C', 'S'], 'votes': 1},
#  {'v': ['M', 'T', 'A', 'J', 'N'], 'votes': 1},
#  {'v': ['M', 'T', 'A', 'G'], 'votes': 1},
#  {'v': ['M', 'T', 'A', 'D', 'O'], 'votes': 1},
#  {'v': ['M', 'T', 'I', 'P', 'S'], 'votes': 1},
#  {'v': ['M', 'J'], 'votes': 42},
#  {'v': ['M', 'J', 'N'], 'votes': 6},
#  {'v': ['M', 'J', 'N', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'N', 'P', 'O'], 'votes': 1},
#  {'v': ['M', 'J', 'N', 'P', 'S'], 'votes': 2},
#  {'v': ['M', 'J', 'N', 'O', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'N', 'C', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'N', 'C', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'N', 'T', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'N', 'T', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'N', 'R', 'P'], 'votes': 2},
#  {'v': ['M', 'J', 'N', 'R', 'C'], 'votes': 1},
#  {'v': ['M', 'J', 'N', 'R', 'T'], 'votes': 2},
#  {'v': ['M', 'J', 'N', 'D'], 'votes': 6},
#  {'v': ['M', 'J', 'N', 'D', 'P'], 'votes': 6},
#  {'v': ['M', 'J', 'N', 'D', 'C'], 'votes': 9},
#  {'v': ['M', 'J', 'N', 'D', 'T'], 'votes': 3},
#  {'v': ['M', 'J', 'N', 'D', 'R'], 'votes': 5},
#  {'v': ['M', 'J', 'N', 'D', 'S'], 'votes': 48},
#  {'v': ['M', 'J', 'N', 'D', 'A'], 'votes': 2},
#  {'v': ['M', 'J', 'N', 'S'], 'votes': 3},
#  {'v': ['M', 'J', 'N', 'S', 'C'], 'votes': 1},
#  {'v': ['M', 'J', 'N', 'S', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'N', 'S', 'R'], 'votes': 1},
#  {'v': ['M', 'J', 'N', 'S', 'D'], 'votes': 5},
#  {'v': ['M', 'J', 'N', 'A', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'P'], 'votes': 9},
#  {'v': ['M', 'J', 'P', 'N', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'O', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'C', 'R'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'C', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'L', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'T', 'R'], 'votes': 2},
#  {'v': ['M', 'J', 'P', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'R', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'R', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'R', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'G', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'G', 'R'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'G', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'D', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'S', 'L'], 'votes': 4},
#  {'v': ['M', 'J', 'P', 'S', 'R'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'S', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'A', 'N'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'A', 'O'], 'votes': 1},
#  {'v': ['M', 'J', 'P', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'O', 'C', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'O', 'T', 'N'], 'votes': 1},
#  {'v': ['M', 'J', 'O', 'S', 'N'], 'votes': 1},
#  {'v': ['M', 'J', 'C'], 'votes': 7},
#  {'v': ['M', 'J', 'C', 'N', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'P', 'O'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'P', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'P', 'T'], 'votes': 2},
#  {'v': ['M', 'J', 'C', 'P', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'O', 'N'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'O', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'O', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'L'], 'votes': 3},
#  {'v': ['M', 'J', 'C', 'L', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'L', 'T'], 'votes': 2},
#  {'v': ['M', 'J', 'C', 'L', 'R'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'L', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'L', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'T', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'T', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'T', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'R'], 'votes': 2},
#  {'v': ['M', 'J', 'C', 'R', 'N'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'R', 'L'], 'votes': 2},
#  {'v': ['M', 'J', 'C', 'R', 'T'], 'votes': 2},
#  {'v': ['M', 'J', 'C', 'R', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'G', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'G', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'G', 'R'], 'votes': 3},
#  {'v': ['M', 'J', 'C', 'D', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'S', 'N'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'S', 'L'], 'votes': 2},
#  {'v': ['M', 'J', 'C', 'S', 'R'], 'votes': 2},
#  {'v': ['M', 'J', 'C', 'S', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'S', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'C', 'A', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'L'], 'votes': 9},
#  {'v': ['M', 'J', 'L', 'N', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'L', 'P', 'S'], 'votes': 2},
#  {'v': ['M', 'J', 'L', 'P', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'L', 'O', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'L', 'C'], 'votes': 1},
#  {'v': ['M', 'J', 'L', 'C', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'L', 'C', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'L', 'C', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'L', 'R', 'C'], 'votes': 1},
#  {'v': ['M', 'J', 'L', 'R', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'L', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'L', 'G', 'O'], 'votes': 2},
#  {'v': ['M', 'J', 'L', 'D', 'G'], 'votes': 2},
#  {'v': ['M', 'J', 'L', 'D', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'L', 'A', 'R'], 'votes': 2},
#  {'v': ['M', 'J', 'T'], 'votes': 6},
#  {'v': ['M', 'J', 'T', 'N', 'O'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'N', 'R'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'N', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'P', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'P', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'O', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'C', 'N'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'C', 'P'], 'votes': 2},
#  {'v': ['M', 'J', 'T', 'L', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'L', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'G', 'R'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'D'], 'votes': 2},
#  {'v': ['M', 'J', 'T', 'D', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'S', 'N'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'S', 'O'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'T', 'S', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'R'], 'votes': 18},
#  {'v': ['M', 'J', 'R', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'P', 'C'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'O'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'O', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'C'], 'votes': 4},
#  {'v': ['M', 'J', 'R', 'C', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'C', 'O'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'C', 'T'], 'votes': 2},
#  {'v': ['M', 'J', 'R', 'C', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'C', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'C', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'L', 'I'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'T', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'T', 'S'], 'votes': 3},
#  {'v': ['M', 'J', 'R', 'T', 'I'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'G', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'D', 'N'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'D', 'P'], 'votes': 3},
#  {'v': ['M', 'J', 'R', 'D', 'C'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'D', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'S', 'O'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'S', 'C'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'S', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'R', 'A'], 'votes': 3},
#  {'v': ['M', 'J', 'R', 'A', 'C'], 'votes': 3},
#  {'v': ['M', 'J', 'R', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'G'], 'votes': 2},
#  {'v': ['M', 'J', 'G', 'N', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'G', 'P', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'G', 'P', 'R'], 'votes': 1},
#  {'v': ['M', 'J', 'G', 'C', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'G', 'C', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'G', 'T', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'G', 'R', 'C'], 'votes': 1},
#  {'v': ['M', 'J', 'G', 'R', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'G', 'R', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'G', 'D', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'G', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'D'], 'votes': 11},
#  {'v': ['M', 'J', 'D', 'N'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'N', 'P'], 'votes': 2},
#  {'v': ['M', 'J', 'D', 'N', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'N', 'R'], 'votes': 2},
#  {'v': ['M', 'J', 'D', 'N', 'S'], 'votes': 3},
#  {'v': ['M', 'J', 'D', 'P'], 'votes': 3},
#  {'v': ['M', 'J', 'D', 'P', 'C'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'P', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'P', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'P', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'P', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'O', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'C'], 'votes': 2},
#  {'v': ['M', 'J', 'D', 'C', 'O'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'C', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'C', 'R'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'C', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'C', 'S'], 'votes': 6},
#  {'v': ['M', 'J', 'D', 'T', 'P'], 'votes': 11},
#  {'v': ['M', 'J', 'D', 'T', 'O'], 'votes': 2},
#  {'v': ['M', 'J', 'D', 'T', 'C'], 'votes': 4},
#  {'v': ['M', 'J', 'D', 'T', 'L'], 'votes': 3},
#  {'v': ['M', 'J', 'D', 'T', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'T', 'A'], 'votes': 2},
#  {'v': ['M', 'J', 'D', 'R', 'P'], 'votes': 3},
#  {'v': ['M', 'J', 'D', 'R', 'C'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'R', 'T'], 'votes': 3},
#  {'v': ['M', 'J', 'D', 'R', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'S'], 'votes': 3},
#  {'v': ['M', 'J', 'D', 'S', 'N'], 'votes': 7},
#  {'v': ['M', 'J', 'D', 'S', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'S', 'O'], 'votes': 2},
#  {'v': ['M', 'J', 'D', 'S', 'C'], 'votes': 3},
#  {'v': ['M', 'J', 'D', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'D', 'S', 'R'], 'votes': 2},
#  {'v': ['M', 'J', 'D', 'S', 'G'], 'votes': 2},
#  {'v': ['M', 'J', 'D', 'S', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'S'], 'votes': 5},
#  {'v': ['M', 'J', 'S', 'N', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'S', 'N', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'S', 'N', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'S', 'P', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'S', 'C'], 'votes': 2},
#  {'v': ['M', 'J', 'S', 'C', 'D'], 'votes': 2},
#  {'v': ['M', 'J', 'S', 'C', 'A'], 'votes': 1},
#  {'v': ['M', 'J', 'S', 'L'], 'votes': 2},
#  {'v': ['M', 'J', 'S', 'L', 'N'], 'votes': 1},
#  {'v': ['M', 'J', 'S', 'R', 'G'], 'votes': 1},
#  {'v': ['M', 'J', 'S', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'S', 'D', 'N'], 'votes': 2},
#  {'v': ['M', 'J', 'S', 'D', 'C'], 'votes': 1},
#  {'v': ['M', 'J', 'S', 'D', 'L'], 'votes': 1},
#  {'v': ['M', 'J', 'A'], 'votes': 4},
#  {'v': ['M', 'J', 'A', 'P', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'A', 'C'], 'votes': 1},
#  {'v': ['M', 'J', 'A', 'C', 'S'], 'votes': 1},
#  {'v': ['M', 'J', 'A', 'R'], 'votes': 1},
#  {'v': ['M', 'J', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'J', 'A', 'D', 'P'], 'votes': 1},
#  {'v': ['M', 'J', 'A', 'D', 'T'], 'votes': 1},
#  {'v': ['M', 'J', 'A', 'D', 'R'], 'votes': 1},
#  {'v': ['M', 'J', 'A', 'D', 'S'], 'votes': 1},
#  {'v': ['M', 'R'], 'votes': 33},
#  {'v': ['M', 'R', 'N', 'D', 'C'], 'votes': 1},
#  {'v': ['M', 'R', 'N', 'A', 'P'], 'votes': 1},
#  {'v': ['M', 'R', 'P'], 'votes': 9},
#  {'v': ['M', 'R', 'P', 'O', 'J'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'O', 'G'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'C', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'L', 'C'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'L', 'D'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'T'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'J', 'N'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'J', 'T'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'S'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'S', 'N'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'S', 'D'], 'votes': 1},
#  {'v': ['M', 'R', 'P', 'A', 'D'], 'votes': 1},
#  {'v': ['M', 'R', 'O'], 'votes': 2},
#  {'v': ['M', 'R', 'O', 'C', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'O', 'L', 'A'], 'votes': 1},
#  {'v': ['M', 'R', 'O', 'G', 'P'], 'votes': 1},
#  {'v': ['M', 'R', 'C'], 'votes': 8},
#  {'v': ['M', 'R', 'C', 'P'], 'votes': 2},
#  {'v': ['M', 'R', 'C', 'P', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'P', 'J'], 'votes': 2},
#  {'v': ['M', 'R', 'C', 'P', 'D'], 'votes': 2},
#  {'v': ['M', 'R', 'C', 'P', 'S'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'O', 'D'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'L'], 'votes': 2},
#  {'v': ['M', 'R', 'C', 'L', 'S'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'T', 'O'], 'votes': 2},
#  {'v': ['M', 'R', 'C', 'T', 'A'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'J'], 'votes': 3},
#  {'v': ['M', 'R', 'C', 'J', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'J', 'G'], 'votes': 2},
#  {'v': ['M', 'R', 'C', 'J', 'S'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'G'], 'votes': 2},
#  {'v': ['M', 'R', 'C', 'G', 'S'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'D', 'T'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'D', 'A'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'S', 'T'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'S', 'J'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'A', 'O'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'A', 'G'], 'votes': 1},
#  {'v': ['M', 'R', 'C', 'A', 'S'], 'votes': 1},
#  {'v': ['M', 'R', 'L'], 'votes': 3},
#  {'v': ['M', 'R', 'L', 'N', 'T'], 'votes': 1},
#  {'v': ['M', 'R', 'L', 'P'], 'votes': 1},
#  {'v': ['M', 'R', 'L', 'P', 'G'], 'votes': 1},
#  {'v': ['M', 'R', 'L', 'C', 'J'], 'votes': 3},
#  {'v': ['M', 'R', 'L', 'T'], 'votes': 2},
#  {'v': ['M', 'R', 'L', 'T', 'P'], 'votes': 1},
#  {'v': ['M', 'R', 'L', 'J', 'C'], 'votes': 1},
#  {'v': ['M', 'R', 'L', 'J', 'G'], 'votes': 1},
#  {'v': ['M', 'R', 'L', 'G', 'J'], 'votes': 1},
#  {'v': ['M', 'R', 'T'], 'votes': 6},
#  {'v': ['M', 'R', 'T', 'N', 'S'], 'votes': 1},
#  {'v': ['M', 'R', 'T', 'P'], 'votes': 2},
#  {'v': ['M', 'R', 'T', 'P', 'S'], 'votes': 1},
#  {'v': ['M', 'R', 'T', 'C', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'T', 'C', 'J'], 'votes': 1},
#  {'v': ['M', 'R', 'T', 'C', 'S'], 'votes': 1},
#  {'v': ['M', 'R', 'T', 'J', 'O'], 'votes': 1},
#  {'v': ['M', 'R', 'T', 'G', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'R', 'T', 'A'], 'votes': 1},
#  {'v': ['M', 'R', 'T', 'A', 'N'], 'votes': 2},
#  {'v': ['M', 'R', 'J'], 'votes': 12},
#  {'v': ['M', 'R', 'J', 'N', 'D'], 'votes': 2},
#  {'v': ['M', 'R', 'J', 'O', 'C'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'C'], 'votes': 2},
#  {'v': ['M', 'R', 'J', 'C', 'P'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'C', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'C', 'T'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'C', 'S'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'L', 'C'], 'votes': 2},
#  {'v': ['M', 'R', 'J', 'L', 'T'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'T'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'T', 'P'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'T', 'O'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'T', 'C'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'T', 'D'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'D', 'G'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'S'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'S', 'T'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'A', 'C'], 'votes': 2},
#  {'v': ['M', 'R', 'J', 'A', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'J', 'A', 'D'], 'votes': 2},
#  {'v': ['M', 'R', 'G'], 'votes': 2},
#  {'v': ['M', 'R', 'G', 'C'], 'votes': 1},
#  {'v': ['M', 'R', 'G', 'T', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'G', 'J', 'S'], 'votes': 1},
#  {'v': ['M', 'R', 'D', 'C', 'J'], 'votes': 1},
#  {'v': ['M', 'R', 'D', 'C', 'A'], 'votes': 1},
#  {'v': ['M', 'R', 'D', 'L', 'J'], 'votes': 1},
#  {'v': ['M', 'R', 'D', 'T', 'G'], 'votes': 2},
#  {'v': ['M', 'R', 'D', 'J'], 'votes': 1},
#  {'v': ['M', 'R', 'D', 'J', 'C'], 'votes': 1},
#  {'v': ['M', 'R', 'D', 'G', 'C'], 'votes': 1},
#  {'v': ['M', 'R', 'D', 'S', 'L'], 'votes': 1},
#  {'v': ['M', 'R', 'D', 'S', 'J'], 'votes': 1},
#  {'v': ['M', 'R', 'D', 'A', 'P'], 'votes': 1},
#  {'v': ['M', 'R', 'S'], 'votes': 3},
#  {'v': ['M', 'R', 'S', 'N', 'J'], 'votes': 1},
#  {'v': ['M', 'R', 'S', 'P', 'J'], 'votes': 1},
#  {'v': ['M', 'R', 'S', 'L', 'P'], 'votes': 1},
#  {'v': ['M', 'R', 'S', 'T', 'N'], 'votes': 1},
#  {'v': ['M', 'R', 'S', 'T', 'G'], 'votes': 1},
#  {'v': ['M', 'R', 'S', 'J'], 'votes': 1},
#  {'v': ['M', 'R', 'A'], 'votes': 4},
#  {'v': ['M', 'R', 'A', 'N', 'G'], 'votes': 2},
#  {'v': ['M', 'R', 'A', 'P', 'C'], 'votes': 1},
#  {'v': ['M', 'R', 'A', 'O', 'C'], 'votes': 1},
#  {'v': ['M', 'R', 'A', 'C'], 'votes': 1},
#  {'v': ['M', 'R', 'A', 'T'], 'votes': 1},
#  {'v': ['M', 'R', 'A', 'J'], 'votes': 1},
#  {'v': ['M', 'R', 'A', 'J', 'C'], 'votes': 1},
#  {'v': ['M', 'R', 'A', 'G', 'J'], 'votes': 1},
#  {'v': ['M', 'G'], 'votes': 13},
#  {'v': ['M', 'G', 'N'], 'votes': 1},
#  {'v': ['M', 'G', 'N', 'L', 'O'], 'votes': 1},
#  {'v': ['M', 'G', 'N', 'T', 'O'], 'votes': 1},
#  {'v': ['M', 'G', 'N', 'R', 'P'], 'votes': 1},
#  {'v': ['M', 'G', 'N', 'R', 'J'], 'votes': 1},
#  {'v': ['M', 'G', 'N', 'S', 'J'], 'votes': 1},
#  {'v': ['M', 'G', 'P'], 'votes': 1},
#  {'v': ['M', 'G', 'P', 'D', 'O'], 'votes': 1},
#  {'v': ['M', 'G', 'O', 'N', 'C'], 'votes': 1},
#  {'v': ['M', 'G', 'C'], 'votes': 2},
#  {'v': ['M', 'G', 'C', 'O', 'J'], 'votes': 1},
#  {'v': ['M', 'G', 'C', 'L'], 'votes': 1},
#  ...]

# %%
# with open('./clean/agg_'+race_key+'_dedupe.json', 'w') as f:
#     json.dump(ret, f, indent=2)
